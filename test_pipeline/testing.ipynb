# %%
run main.py
# Out:
# INFO:root:Main directory: /blue/adamginsburg/d.jeff/SgrB2DS_COMAnalysis/scripts/test_pipeline
# INFO:root:Creating home directory for all results: results/DSi/CH3CH2CN
# INFO:__main__:Creating directory for results of representative line measurement: results/DSi/CH3CH2CN/representativelinetests
# WARNING: AstropyDeprecationWarning: Using LMLSQFitter for models with bounds is now deprecated since astropy 7.0. We recommend you use another non-linear fitter such as TRFLSQFitter or DogBoxLSQFitter instead as these have full support for fitting models with bounds [astropy.modeling.fitting]
# WARNING:astroquery:AstropyDeprecationWarning: Using LMLSQFitter for models with bounds is now deprecated since astropy 7.0. We recommend you use another non-linear fitter such as TRFLSQFitter or DogBoxLSQFitter instead as these have full support for fitting models with bounds
# <class 'pathlib.PosixPath'>
#        QNs          RestFrequency    ...  ModelBrightness     ModelNupper
# ...

# %%
model_fit_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model_fit_table
#
# NameError: name 'model_fit_table' is not defined

# %%
from utilities import *
