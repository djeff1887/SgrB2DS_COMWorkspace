# %%
run bootstrap_makesinglemapfigure.py
# Out:
# Mode: ntot
# Source: DSiv
#
# Savefigpath /blue/adamginsburg/d.jeff/repos/668d89885ebb5bfe9c01ccfc/figures/SgrB2DS_EthanolMethanol/NtotMaps/DSiv/nov2024_1_firstrun_removesDS2exclusions/ already exists
# The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58090.615305 from DATE-OBS'. [astropy.wcs.wcs]
# Saving figure at /blue/adamginsburg/d.jeff/repos/668d89885ebb5bfe9c01ccfc/figures/SgrB2DS_EthanolMethanol/NtotMaps/DSiv/nov2024_1_firstrun_removesDS2exclusions/withmethanolradius&legend_ntotmap_allspw_withnans_weighted_useintercept_3sigma.png
# Saved

# %%
srcradius.value
# Out:
# 4000.0

# %%
data_in_okradius=hdu.data*mask
plt.imshow(data_in_okradius,origin='lower',vmax=500,cmap=cm)
plt.colorbar()
