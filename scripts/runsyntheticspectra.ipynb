# %%
run new_makesyntheticspectra_composite.py
# Out:
# Collecting spectra from /orange/adamginsburg/sgrb2/2017.1.00114.S/desmond/SgrB2DSminicubes/DSVI/field2originals_K/*spw*.fits
# Rotational temperature: 250.0 K
# Spectra and stds are sequential order
# Absolute model line width: 4.024309176807379 km / s
#
# Getting ready - spw0
# Corrected decreasing frequency axis
# Plotting model spectra
# Gathering CDMS table parameters
# Begin model loops for  CH3OCHO
# Begin model loops for  CH3CHO
# Begin model loops for  C2H5OH
# Begin model loops for  CH3OCH3
# Begin model loops for  DCN
# No transitions for  OCS  in spw0. Continue
# Begin model loops for  13CH3OH
# Begin model loops for  H2CO
# No transitions for  HC3N  in spw0. Continue
# No transitions for  C(18)O  in spw0. Continue
# No transitions for  13CS  in spw0. Continue
# Begin model loops for  SO2
# Begin model loops for  NH2CHO
# No transitions for  HNCO  in spw0. Continue
# No transitions for  SO  in spw0. Continue
# Begin model loops for  SiO
# Begin model loops for  H2S
# Begin model loops for  c-HCCCH
# No transitions for HC3N v7=1 in spw0. Continue
# No transitions for  H213CO  in spw0. Continue
# No transitions for  13CH3CN  in spw0. Continue
# Begin model loops for  CH2CHCN
# Begin model loops for  18OCS
# Begin model loops for  CH3NCO, vb = 0
# Begin model loops for  CH3CH2CN
# 58003 CH3COCH3
#  TAG    NAME   NLINE QLOG1  QLOG2  QLOG3  QLOG4 QLOG5  QLOG6  QLOG7  VER
# ----- -------- ----- ------ ------ ------ ----- ------ ------ ------ ---
# 58003 CH3COCH3 61834 7.1904 6.7212 6.1567 5.129 4.7774 4.3268 3.9163  1*
#     FREQ      ERR    LGINT   DR    ELO    GUP  TAG  QNFMT   QN'      QN"
#     MHz       MHz   nm2 MHz       1 / cm
# ----------- ------- ------- --- --------- --- ----- ----- -------- --------
# 216419.7859  8.8117 -7.1577   3 1073.7686 250 58003  1404 623428 1 623329 1
# 216420.2309  8.8151 -6.8567   3 1073.7686 500 58003  1404 623428 1 623329 2
# 216473.7931  0.1614 -5.7961   3  382.7883 316 58003  1404 391425 1 391326 2
# 216473.7931  0.1614 -5.7961   3  382.7883 316 58003  1404 391525 1 391426 2
# 216473.8826  0.1632   -5.62   3  382.7883 474 58003  1404 391425 1 391326 1
# 216473.8826  0.1632 -6.0971   3  382.7883 158 58003  1404 391525 1 391426 1
# 216479.9236  0.1575  -5.194   3  382.8172 999 58003  1404 391425 0 391326 1
# 216479.9236  0.1575 -5.1941   3  382.8172 999 58003  1404 391525 0 391426 1
#  216485.923  0.1874 -5.3982   3   382.846 790 58003  1404 391425 0 391326 0
#         ...     ...     ... ...       ... ...   ...   ...      ...      ...
#  218234.134  0.1012 -5.1607   3  312.8511 999 58003  1404 361125 0 361026 1
#  218234.134  0.1012 -5.1607   3  312.8511 999 58003  1404 361225 0 361126 1
#  218234.134  0.1012 -6.4437   3  312.8511 999 58003  1404 361225 0 361026 1
#  218240.167  0.0276 -7.9272   3   15.0744  34 58003  1404  8 7 1 1  7 4 4 1
# 218245.6367  6.2195  -6.332   3  490.8499 999 58003  1404 3838 0 0 3837 1 1
# 218274.4619  60.394 -7.2137   3 1347.7161 822 58003  1404 684721 0 684622 0
# 218279.9236 36.9109 -7.0814   3 1168.1759 508 58003  1404 634519 1 634420 2
# 218281.3692  0.8058 -5.9151   3  617.5126 582 58003  1404 482226 0 482127 0
# 218281.3766  0.8058 -5.6933   3  617.5126 970 58003  1404 482326 0 482227 0
# 218291.7363  0.1076  -8.252   3   44.4153 162 58003  1404 13 8 5 1 12 8 5 1
# Length = 212 rows
# Partition function: 8675876.376772262
# Begin model loops for  CH3COCH3
# Begin CH3OH modeling
#
# yay
# Getting ready - spw1
# Corrected decreasing frequency axis
# Plotting model spectra
# Gathering CDMS table parameters
# Begin model loops for  CH3OCHO
# Begin model loops for  CH3CHO
# Begin model loops for  C2H5OH
# Begin model loops for  CH3OCH3
# No transitions for  DCN  in spw1. Continue
# Begin model loops for  OCS
# Begin model loops for  13CH3OH
# Begin model loops for  H2CO
# Begin model loops for  HC3N
# Begin model loops for  C(18)O
# No transitions for  13CS  in spw1. Continue
# Begin model loops for  SO2
# Begin model loops for  NH2CHO
# Begin model loops for  HNCO
# Begin model loops for  SO
# No transitions for  SiO  in spw1. Continue
# No transitions for  H2S  in spw1. Continue
# Begin model loops for  c-HCCCH
# Begin model loops for HC3N v7=1
# Begin model loops for  H213CO
# No transitions for  13CH3CN  in spw1. Continue
# Begin model loops for  CH2CHCN
# No transitions for  18OCS  in spw1. Continue
# Begin model loops for  CH3NCO, vb = 0
# Begin model loops for  CH3CH2CN
# 58003 CH3COCH3
#  TAG    NAME   NLINE QLOG1  QLOG2  QLOG3  QLOG4 QLOG5  QLOG6  QLOG7  VER
# ----- -------- ----- ------ ------ ------ ----- ------ ------ ------ ---
# 58003 CH3COCH3 61834 7.1904 6.7212 6.1567 5.129 4.7774 4.3268 3.9163  1*
#     FREQ      ERR    LGINT   DR    ELO    GUP  TAG  QNFMT   QN'      QN"
#     MHz       MHz   nm2 MHz       1 / cm
# ----------- ------- ------- --- --------- --- ----- ----- -------- --------
# 218274.4619  60.394 -7.2137   3 1347.7161 822 58003  1404 684721 0 684622 0
# 218279.9236 36.9109 -7.0814   3 1168.1759 508 58003  1404 634519 1 634420 2
# 218281.3692  0.8058 -5.9151   3  617.5126 582 58003  1404 482226 0 482127 0
# 218281.3766  0.8058 -5.6933   3  617.5126 970 58003  1404 482326 0 482227 0
# 218291.7363  0.1076  -8.252   3   44.4153 162 58003  1404 13 8 5 1 12 8 5 1
# 218295.1816   0.116 -5.5643   3  312.8735 438 58003  1404 361125 0 361026 0
# 218295.1816   0.116 -5.3425   3  312.8735 730 58003  1404 361225 0 361126 0
# 218320.5101  0.7763 -5.4889   3  617.4969 999 58003  1404 482226 0 482127 1
# 218320.5199  0.7763 -5.4889   3  617.4969 999 58003  1404 482326 0 482227 1
#         ...     ...     ... ...       ... ...   ...   ...      ...      ...
# 219913.7657  4.4604 -6.4602   3  693.1453 380 58003  1404 4740 7 1 4739 8 2
# 219963.5595  4.3753 -5.8581   3  693.1278 999 58003  1404 4740 7 0 4739 8 1
# 219966.1383  27.145 -6.7999   3 1378.7602 999 58003  1404 704030 0 703931 1
# 219996.9407  0.0548 -5.1543   3  227.9729 999 58003  1404 32 725 0 32 726 1
# 219996.9407  0.0548 -6.5555   3  227.9729 999 58003  1404 32 825 0 32 726 1
# 219996.9407  0.0548 -6.5555   3  227.9729 999 58003  1404 32 725 0 32 626 1
# 219996.9407  0.0548 -5.1543   3  227.9729 999 58003  1404 32 825 0 32 626 1
# 220009.7239  4.6638 -6.0622   3  693.1105 950 58003  1404 4740 7 0 4739 8 0
#  220009.724  4.6638  -6.284   3  693.1105 570 58003  1404 4740 8 0 4739 9 0
# 220093.7461 72.6879 -7.0464   3 1424.8499 999 58003  1404 704822 0 704723 1
# Length = 186 rows
# Partition function: 8675876.376772262
# Begin model loops for  CH3COCH3
# Begin CH3OH modeling
#
# yay
# Getting ready - spw2
# Plotting model spectra
# Gathering CDMS table parameters
# Begin model loops for  CH3OCHO
# Begin model loops for  CH3CHO
# Begin model loops for  C2H5OH
# Begin model loops for  CH3OCH3
# No transitions for  DCN  in spw2. Continue
# Begin model loops for  OCS
# Begin model loops for  13CH3OH
# Begin model loops for  H2CO
# No transitions for  HC3N  in spw2. Continue
# No transitions for  C(18)O  in spw2. Continue
# Begin model loops for  13CS
# Begin model loops for  SO2
# Begin model loops for  NH2CHO
# Begin model loops for  HNCO
# No transitions for  SO  in spw2. Continue
# No transitions for  SiO  in spw2. Continue
# No transitions for  H2S  in spw2. Continue
# Begin model loops for  c-HCCCH
# No transitions for HC3N v7=1 in spw2. Continue
# Begin model loops for  H213CO
# Begin model loops for  13CH3CN
# Begin model loops for  CH2CHCN
# No transitions for  18OCS  in spw2. Continue
# Begin model loops for  CH3NCO, vb = 0
# Begin model loops for  CH3CH2CN
# 58003 CH3COCH3
#  TAG    NAME   NLINE QLOG1  QLOG2  QLOG3  QLOG4 QLOG5  QLOG6  QLOG7  VER
# ----- -------- ----- ------ ------ ------ ----- ------ ------ ------ ---
# 58003 CH3COCH3 61834 7.1904 6.7212 6.1567 5.129 4.7774 4.3268 3.9163  1*
#     FREQ      ERR    LGINT   DR    ELO    GUP  TAG  QNFMT   QN'      QN"
#     MHz       MHz   nm2 MHz       1 / cm
# ----------- ------- ------- --- --------- --- ----- ----- -------- --------
# 230364.1493  0.0209 -5.9964   3   22.5391 210 58003  1404 10 6 5 0  9 3 6 0
# 230368.6118  0.6384 -7.1508   3   157.831 752 58003  1404 2318 6 0 2315 8 1
# 230369.0085  5.7948 -6.5395   3  655.1933 364 58003  1404 4541 5 1 4540 6 2
# 230385.6241  0.1877 -7.5678   3  109.3608 624 58003  1404 1916 3 0 1913 7 1
# 230396.5409  0.4246 -5.9679   3  551.8281 372 58003  1404 461927 1 461828 2
#  230396.541  0.4246 -5.9679   3  551.8281 372 58003  1404 462027 1 461928 2
# 230396.5424  0.4245  -6.269   3  551.8282 186 58003  1404 461927 1 461828 1
# 230396.5425  0.4245 -5.7919   3  551.8282 558 58003  1404 462027 1 461928 1
# 230402.4862  0.8003 -7.2431   3  157.8345 282 58003  1404 2318 5 1 2315 8 1
#         ...     ...     ... ...       ... ...   ...   ...      ...      ...
# 232050.2434  0.8288 -7.6901   3  426.4097 486 58003  1404 401922 1 392019 1
# 232050.2623  2.2047 -6.1309   3  374.3624 999 58003  1404 362412 0 362115 1
# 232068.4424  0.8347 -7.2642   3  426.4365 999 58003  1404 401922 0 392019 1
# 232086.6767  0.8893 -7.4684   3  426.4632 810 58003  1404 401922 0 392019 0
# 232090.1938  1.1691 -6.7382   3  256.8878 366 58003  1404 301911 0 301614 0
# 232111.6414 41.3305 -7.0185   3 1247.2467 786 58003  1404 654718 1 654619 1
# 232117.2067 41.3064 -7.4956   3 1247.2465 262 58003  1404 654719 1 654620 1
# 232181.9215  1.0659 -6.3132   3  256.8671 976 58003  1404 301911 0 301614 1
# 232210.2379  0.1463  -6.811   3  126.8337  86 58003  1404 2115 7 1 2016 4 1
# 232213.4241  6.5071 -6.5831   3  633.4318 356 58003  1404 4441 3 1 4440 4 2
# Length = 136 rows
# Partition function: 8675876.376772262
# Begin model loops for  CH3COCH3
# Begin CH3OH modeling
#
# yay
# Getting ready - spw3
# Plotting model spectra
# Gathering CDMS table parameters
# Begin model loops for  CH3OCHO
# Begin model loops for  CH3CHO
# Begin model loops for  C2H5OH
# Begin model loops for  CH3OCH3
# No transitions for  DCN  in spw3. Continue
# No transitions for  OCS  in spw3. Continue
# Begin model loops for  13CH3OH
# Begin model loops for  H2CO
# No transitions for  HC3N  in spw3. Continue
# No transitions for  C(18)O  in spw3. Continue
# No transitions for  13CS  in spw3. Continue
# Begin model loops for  SO2
# Begin model loops for  NH2CHO
# No transitions for  HNCO  in spw3. Continue
# No transitions for  SO  in spw3. Continue
# No transitions for  SiO  in spw3. Continue
# No transitions for  H2S  in spw3. Continue
# Begin model loops for  c-HCCCH
# No transitions for HC3N v7=1 in spw3. Continue
# No transitions for  H213CO  in spw3. Continue
# No transitions for  13CH3CN  in spw3. Continue
# Begin model loops for  CH2CHCN
# No transitions for  18OCS  in spw3. Continue
# Begin model loops for  CH3NCO, vb = 0
# Begin model loops for  CH3CH2CN
# 58003 CH3COCH3
#  TAG    NAME   NLINE QLOG1  QLOG2  QLOG3  QLOG4 QLOG5  QLOG6  QLOG7  VER
# ----- -------- ----- ------ ------ ------ ----- ------ ------ ------ ---
# 58003 CH3COCH3 61834 7.1904 6.7212 6.1567 5.129 4.7774 4.3268 3.9163  1*
#     FREQ      ERR    LGINT   DR    ELO    GUP  TAG  QNFMT   QN'      QN"
#     MHz       MHz   nm2 MHz       1 / cm
# ----------- ------- ------- --- --------- --- ----- ----- -------- --------
# 232261.5545 66.1611 -7.8145   3 1432.2405 282 58003  1404 704921 1 704822 1
# 232267.1634  1.1107 -6.9161   3  256.8465 244 58003  1404 301911 1 301614 2
# 232271.2227  0.2259  -8.173   3   99.9404 592 58003  1404 1816 3 0 1813 5 1
# 232273.0822  0.1105 -7.6636   3   76.8956 210 58003  1404 17 9 8 1 17 611 1
# 232285.7721  1.1124 -7.2172   3  256.8464 122 58003  1404 301911 1 301614 1
# 232288.7228  0.1038 -7.8397   3   76.8957 140 58003  1404 17 9 8 1 17 611 2
# 232293.9943 41.3546 -6.5918   3  1247.166 999 58003  1404 654719 0 654620 1
# 232322.9345 11.5901 -7.3641   3 1213.9655 266 58003  1404 663630 1 663531 1
# 232323.0797 11.5936 -7.0631   3 1213.9655 532 58003  1404 663630 1 663531 2
#         ...     ...     ... ...       ... ...   ...   ...      ...      ...
# 234038.7451  0.1669 -5.5152   3  417.1478 999 58003  1404 411427 0 411328 1
# 234038.7451  0.1669 -5.2327   3  417.1478 999 58003  1404 411527 0 411428 1
# 234038.7451  0.1669 -5.4877   3  417.1478 999 58003  1404 411527 0 411328 1
# 234039.3178  0.7153 -6.9339   3  191.2124 318 58003  1404 261610 0 261313 0
# 234042.2275  0.1716 -5.7981   3  417.1183 332 58003  1404 411427 1 411328 2
# 234042.2275  0.1716 -5.7981   3  417.1183 332 58003  1404 411527 1 411428 2
# 234042.3176   0.174  -5.622   3  417.1183 498 58003  1404 411427 1 411328 1
# 234042.3176   0.174 -6.0991   3  417.1183 166 58003  1404 411527 1 411428 1
# 234052.9881  0.1821 -6.2236   3  144.1542 752 58003  1404 231311 0 2214 8 1
#   234089.67  0.2692 -8.1321   3   99.9734 148 58003  1404 1816 2 1 1813 5 2
# Length = 196 rows
# Partition function: 8675876.376772262
# Begin model loops for  CH3COCH3
# Begin CH3OH modeling
#
# yay

# %%
species_catdir=cdms_catdir[cdms_catdir['molecule'] == cdmsnamelist[' H213CO ']]
species_catdirtag=str(species_catdir['tag'][0])
scatdir_qrot300=10**species_catdir['lg(Q(300))']
scatdir_qrot300
# Out:
# <Column name='lg(Q(300))' dtype='float64' length=1>
# 2955.969849504591

# %%
linemodelhome='/blue/adamginsburg/d.jeff/SgrB2DS_COMAnalysis/linemodels/'
linemodelversion='firstrelease'
linemodelpath=linemodelhome+f'{linemodelversion}/{source}/'
os.mkdir(linemodelpath)

# %%
'''Quantum numbers will be borked in some cases until I figure out how to parse them properly from the CDMS tables'''
for molecule in linedetections.keys():
    tempmolname=molecule.replace(' ','')
    if tempmolname == 'CH3NCO,vb=0':
        savemolname = 'CH3NCO'
    if tempmolname == 'C(18)O':
        savemolname = 'C18O'
        pdb.set_trace()
    if tempmolname == 'HC3Nv7=1':
        savemolname = 'HC3Nv7_1'
    else:
        savemolname = tempmolname
    table=linedetections[molecule]
    savetablepath=linemodelpath+f'{savemolname}.fits'
    table.write(savetablepath,overwrite=True)
    #sys.exit()
# Out:
# > /scratch/local/51067832/ipykernel_3118498/2510526340.py(9)<module>()
#       7         savemolname = 'C18O'
#       8         pdb.set_trace()
# ----> 9     if tempmolname == 'HC3Nv7=1':
#      10         savemolname = 'HC3Nv7_1'
#      11     else:
# ipdb>  c

# %%
table
# Out:
# <QTable length=10>
#        QNs          RestFrequency    ...  ModelBrightness      ModelNupper
#                          GHz         ...         K               1 / cm2
#       str17            float64       ...      float64            float64
# ----------------- ------------------ ... ------------------ ------------------
# 13(9,--)-12(9,--) 231.88151530000002 ... 3.2288535149579234  3696157152999.037
# 13(8,--)-12(8,--)        231.9553712 ...   2.72620006648061 2612831819024.0645
# 13(7,--)-12(7,--) 232.02060930000002 ... 4.2225345545581625  3547233220483.706
# 13(6,--)-12(6,--) 232.07720319999999 ...  12.06370512564475  9248156144283.637
# 13(5,--)-12(5,--)        232.1251297 ...  8.222315113669795   5787508842356.31
# 13(4,--)-12(4,--) 232.16436919999998 ... 10.463352204341565  6954522862041.115
# 13(3,--)-12(3,--)        232.1949056 ...  24.71190595385144  16045889688922.68
# 13(2,--)-12(2,--)        232.2167263 ... 14.337572440921942  8885403639630.896
# 13(1,--)-12(1,--)        232.2298223 ...  15.49609938351482  9446850912999.287
# 13(0,--)-12(0,--)        232.2341883 ... 15.898639741818055  9641792945729.768

# %%
QTable.read(savetablepath)
# Out:
# <QTable length=98>
#      QNs        RestFrequency    ...  ModelBrightness      ModelNupper
#                      GHz         ...         K               1 / cm2
#    bytes13         float64       ...      float64            float64
# ------------- ------------------ ... ------------------ ------------------
#     1816-1715         216.830197 ... 16.825091198307746 66689853319460.086
# 18.216-17.215         216.838889 ...   16.8282876388437  66692685472496.74
# 17.314-16.313         216.958834 ...  7.841188336197336  30433268319166.67
#   20.020-1919         216.962989 ... 3.0949562001636055  72183083350001.69
#   2020-19.119 216.96415710000002 ... 3.0935620963316897  72188266960216.61
#     2020-1919 216.96476500000003 ... 18.744347822559856  72183058508145.53
# 20.120-19.119        216.9659004 ... 18.748622734872594  72188242574001.55
# 20.020-19.019        216.9662462 ...  18.74422397012688  72183079723378.03
#     2020-1919          216.96742 ... 18.752641506068112  72188263253597.84
#           ...                ... ...                ...                ...
# 1912.7-1812.6 233.65534200000002 ...   8.08522642079074  46576886638841.85
# 1912.8-1812.7 233.65534200000002 ...   8.08522642079074  46576886638841.85
# 1912.8-1812.7 233.67098000000001 ...  8.086580183713611   46579045482823.4
# 18.414-17.413          233.75396 ...  17.35116652137907  64389937385608.55
# 18.414-17.413         233.777521 ...  17.35337305402776   64391513738753.8
# 1911.8-1811.7         233.845233 ...  9.486220417582565  49529571508907.03
# 1911.9-1811.8         233.854286 ...  9.488023736534931   49530434149616.4
# 1911.8-1811.7         233.854286 ...  9.488023736534931   49530434149616.4
# 1911.9-1811.8 233.86719300000001 ...  9.487564742118877   49532353252353.0
