# %%
run main.py
# Out:
# INFO:root:Main directory: /blue/adamginsburg/d.jeff/SgrB2DS_COMAnalysis/scripts/test_pipeline
# INFO:root:Creating directory for results of representative line measurement: results/DSi/representativelinetests
# INFO:root:Selecting C2H5OH representative line from 5 candidate best lines in ../../linemodels/firstrelease/DSi
#           QNs           RestFrequency ...  ModelBrightness      ModelNupper
#                              GHz      ...         K               1 / cm2
# ----------------------- ------------- ... ------------------ ------------------
# 14(0,14)(2)-13(1,13)(2)   230.9913834 ...  43.77508197342374 259205305799112.06
# 14(0,14)(0)-13(0,13)(0)    232.491318 ... 33.099402199367084 206533585968417.78
# 14(1,14)(0)-13(1,13)(0)   231.6687419 ...  32.94625833796421 206435629497225.06
# 13(2,11)(0)-12(2,10)(0)   230.6725581 ... 30.191965160793213  194763758856287.8
# 19(5,15)(2)-19(4,16)(2)   231.7376214 ... 27.149727926023278 227398196279961.84
# ...

# %%
import os
os.path.exists('..')
# Out:
# True

# %%
from utilities import *
